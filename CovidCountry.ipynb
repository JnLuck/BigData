# %% [markdown]
# <a href="https://colab.research.google.com/github/JnLuck/BigData/blob/main/CovidCountry.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Instalar la librería 'bar-chart-race'
# !pip install bar-chart-race
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 kB 1.6 MB/s eta 0:00:00
# ...

# %%
# Importar pandas
import pandas as pd

# %%
# Leer el archivo CSV
datos = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vTrlZ8WOKT9xvf8iB8y1mLtlz5rTWpflFP_MjNk6iVZD8hUl3fxXTA6BRQBE-UTlcndI9YMY5CBdrdr/pub?gid=80035196&single=true&output=csv",index_col="Fecha",)

# %%
datos
# Out:
#             Perú  Bolivia  Brasil  Argentina  Chile  Mexico  Alemania
# Fecha
# 20/03/2020     1        1       0          0      0       3         0
# 21/03/2020    17       12       2          6      1      11         2
# 22/03/2020    23       13       7          9      2      41         4
# 23/03/2020    36       24       8         17      6      56         6
# 24/03/2020    49       27      19         25      9      54         7
# 25/03/2020    65       36      28         31     14      38         9
# 26/03/2020    74       39      29         33     17      38        10
# 27/03/2020    80       42      36         41     18      49        11
# 28/03/2020    93       44      39         48     21      76        12
# 29/03/2020    97       46      45         51     26      99        14
# 30/03/2020   105       52      51         52     31     120        16
# 31/03/2020   110       55      52         53     35      85        17
# ...

# %%
# Importar la librería 'bar_chart_race' y asignarle el alias 'bcarrera'
import bar_chart_race as bcarrera

# %%
# Crear un gráfico de barras animado utilizando el DataFrame 'datos'
bcarrera.bar_chart_race(df=datos,filename="MovieCountry.mp4")
# Out:
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
