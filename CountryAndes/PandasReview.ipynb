# %%
# Importar libreria pandas
import pandas as pd

# %%
# Leer el archivo CSV
data = pd.read_csv("https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv")

# %%
# Mostramos las 10 primeras filas
data.head(10)
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-08          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-09          NaN        0.0
# 5      AFG      Asia  Afghanistan  2020-01-10          NaN        0.0
# 6      AFG      Asia  Afghanistan  2020-01-11          NaN        0.0
# 7      AFG      Asia  Afghanistan  2020-01-12          NaN        0.0
# 8      AFG      Asia  Afghanistan  2020-01-13          NaN        0.0
# 9      AFG      Asia  Afghanistan  2020-01-14          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# ...

# %%
# Mostramos las 10 ultimas filas o registros
data.tail(10)
# Out:
#        iso_code continent  location        date  total_cases  new_cases  \
# 401032      ZWE    Africa  Zimbabwe  2024-05-03     266362.0        0.0
# 401033      ZWE    Africa  Zimbabwe  2024-05-04     266362.0        0.0
# 401034      ZWE    Africa  Zimbabwe  2024-05-05     266362.0        0.0
# 401035      ZWE    Africa  Zimbabwe  2024-05-06     266362.0        0.0
# 401036      ZWE    Africa  Zimbabwe  2024-05-07     266362.0        0.0
# 401037      ZWE    Africa  Zimbabwe  2024-05-08     266362.0        0.0
# 401038      ZWE    Africa  Zimbabwe  2024-05-09     266362.0        0.0
# 401039      ZWE    Africa  Zimbabwe  2024-05-10     266362.0        0.0
# 401040      ZWE    Africa  Zimbabwe  2024-05-11     266362.0        0.0
# 401041      ZWE    Africa  Zimbabwe  2024-05-12     266362.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 401032               0.429        5740.0         0.0                  0.0
# ...

# %%
# Mostramos la cantidad total de registros
t_registros = len(data)
print(f"Tenemos {t_registros} filas")
# Out:
# Tenemos 401042 filas

# %%
# Creamos un dataframe 'data100' que tendra los primeros 100 registros
data100 = data.head(100)

# %%
data100
# Out:
#    iso_code continent     location        date  total_cases  new_cases  \
# 0       AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 1       AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 2       AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
# 3       AFG      Asia  Afghanistan  2020-01-08          NaN        0.0
# 4       AFG      Asia  Afghanistan  2020-01-09          NaN        0.0
# ..      ...       ...          ...         ...          ...        ...
# 95      AFG      Asia  Afghanistan  2020-04-09        274.0        0.0
# 96      AFG      Asia  Afghanistan  2020-04-10        274.0        0.0
# 97      AFG      Asia  Afghanistan  2020-04-11        274.0        0.0
# 98      AFG      Asia  Afghanistan  2020-04-12        521.0      247.0
# 99      AFG      Asia  Afghanistan  2020-04-13        521.0        0.0
#
#     new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
# Creamos un dataframe 'data100c' que contendra 100 registros y 2 columnas: "Location" y "new_cases_smoothed"
data100c = data100[['location','new_cases_smoothed']]

# %%
data100c
# Out:
#        location  new_cases_smoothed
# 0   Afghanistan                 NaN
# 1   Afghanistan                 NaN
# 2   Afghanistan                 NaN
# 3   Afghanistan                 NaN
# 4   Afghanistan                 NaN
# ..          ...                 ...
# 95  Afghanistan              26.143
# 96  Afghanistan              26.143
# 97  Afghanistan              26.143
# 98  Afghanistan              35.286
# 99  Afghanistan              35.286
#
# [100 rows x 2 columns]

# %%
# Activamos la visualización total de los registroa de un dataframe
# Cuidado! - Volver a activar para no causar demoras con muchos registros
pd.set_option('display.max_rows',None)
data100c
# Out:
#        location  new_cases_smoothed
# 0   Afghanistan                 NaN
# 1   Afghanistan                 NaN
# 2   Afghanistan                 NaN
# 3   Afghanistan                 NaN
# 4   Afghanistan                 NaN
# 5   Afghanistan               0.000
# 6   Afghanistan               0.000
# 7   Afghanistan               0.000
# 8   Afghanistan               0.000
# 9   Afghanistan               0.000
# 10  Afghanistan               0.000
# 11  Afghanistan               0.000
# 12  Afghanistan               0.000
# 13  Afghanistan               0.000
# 14  Afghanistan               0.000
# 15  Afghanistan               0.000
# 16  Afghanistan               0.000
# 17  Afghanistan               0.000
# 18  Afghanistan               0.000
# 19  Afghanistan               0.000
# 20  Afghanistan               0.000
# 21  Afghanistan               0.000
# 22  Afghanistan               0.000
# 23  Afghanistan               0.000
# 24  Afghanistan               0.000
# ...

# %%
# Reestablecemos la visualización a 10
pd.set_option('display.max_rows',10)
data100c
# Out:
#        location  new_cases_smoothed
# 0   Afghanistan                 NaN
# 1   Afghanistan                 NaN
# 2   Afghanistan                 NaN
# 3   Afghanistan                 NaN
# 4   Afghanistan                 NaN
# ..          ...                 ...
# 95  Afghanistan              26.143
# 96  Afghanistan              26.143
# 97  Afghanistan              26.143
# 98  Afghanistan              35.286
# 99  Afghanistan              35.286
#
# [100 rows x 2 columns]

# %%
# Creamos un dataframe 'datau' que contendra las 100 filas y 3 columnas:
# 'location', 'data' y 'new_cases_smoothed'
# mostrar las 100 filas.

data100u = data.tail(100)
datau = data.tail(100)
datau = data100u[['location','new_cases_smoothed']].reset_index(drop=True)
datau.index = datau.index + 1

# %%
pd.set_option('display.max_rows',10)
datau
# Out:
#      location  new_cases_smoothed
# 1    Zimbabwe               4.429
# 2    Zimbabwe               4.429
# 3    Zimbabwe               4.429
# 4    Zimbabwe               4.429
# 5    Zimbabwe               4.429
# ..        ...                 ...
# 96   Zimbabwe               0.000
# 97   Zimbabwe               0.000
# 98   Zimbabwe               0.000
# 99   Zimbabwe               0.000
# 100  Zimbabwe               0.000
#
# [100 rows x 2 columns]

# %%
# Obtenemos registros que corresponden a Perú
data_peru = data[data['location']=="Peru"]

# %%
data_peru
# Out:
#        iso_code      continent location        date  total_cases  new_cases  \
# 279499      PER  South America     Peru  2020-01-05          NaN        0.0
# 279500      PER  South America     Peru  2020-01-06          NaN        0.0
# 279501      PER  South America     Peru  2020-01-07          NaN        0.0
# 279502      PER  South America     Peru  2020-01-08          NaN        0.0
# 279503      PER  South America     Peru  2020-01-09          NaN        0.0
# ...         ...            ...      ...         ...          ...        ...
# 281084      PER  South America     Peru  2024-05-08    4524748.0        0.0
# 281085      PER  South America     Peru  2024-05-09    4524748.0        0.0
# 281086      PER  South America     Peru  2024-05-10    4524748.0        0.0
# 281087      PER  South America     Peru  2024-05-11    4524748.0        0.0
# 281088      PER  South America     Peru  2024-05-12    4524748.0        0.0
#
# ...

# %%
# Reasignamos y creamos el dataframe con solo 3 columnas
data_peru = data[data['location'] == "Peru"][['location', 'date', 'new_cases_smoothed']]
# Visualizamos el dataframe
data_peru
# Out:
#        location        date  new_cases_smoothed
# 279499     Peru  2020-01-05                 NaN
# 279500     Peru  2020-01-06                 NaN
# 279501     Peru  2020-01-07                 NaN
# 279502     Peru  2020-01-08                 NaN
# 279503     Peru  2020-01-09                 NaN
# ...         ...         ...                 ...
# 281084     Peru  2024-05-08                 0.0
# 281085     Peru  2024-05-09                 0.0
# 281086     Peru  2024-05-10                 0.0
# 281087     Peru  2024-05-11                 0.0
# 281088     Peru  2024-05-12                 0.0
#
# [1590 rows x 3 columns]

# %%
# Asegúrate de que la columna 'date' esté en formato de fecha
data_peru['date'] = pd.to_datetime(data_peru['date'])

# Filtrar registros solo para agosto de 2020
data_peru_agosto_2020 = data_peru[(data_peru['date'].dt.year == 2020) & (data_peru['date'].dt.month == 8)]

# %%
data_peru_agosto_2020
# Out:
#        location       date  new_cases_smoothed
# 279708     Peru 2020-08-01            4346.286
# 279709     Peru 2020-08-02            5539.143
# 279710     Peru 2020-08-03            5539.143
# 279711     Peru 2020-08-04            5539.143
# 279712     Peru 2020-08-05            5539.143
# ...         ...        ...                 ...
# 279734     Peru 2020-08-27            8538.714
# 279735     Peru 2020-08-28            8538.714
# 279736     Peru 2020-08-29            8538.714
# 279737     Peru 2020-08-30            7699.143
# 279738     Peru 2020-08-31            7699.143
#
# [31 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# %%
# Crear el gráfico de barras
plt.figure(figsize=(10, 6))
plt.bar(dias_agosto, data_peru_agosto_2020_grouped, color='skyblue')
plt.title('Nuevos casos suavizados en Perú durante agosto de 2020')
plt.xlabel('Agosto')
plt.ylabel('Nuevos casos suavizados')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(dias_agosto)  # Mostrar todos los días del mes en el eje x
plt.show()

# %%
# Filtrar datos de los paises andinos: Perú, Argentina, Bolivia y Chile
paises_andinos = data[(data['location'] == 'Peru') |
                      (data['location'] == 'Argentina') |
                      (data['location'] == 'Bolivia') |
                      (data['location'] == 'Chile')]

# %%
paises_andinos
# Out:
#        iso_code      continent   location        date  total_cases  new_cases  \
# 14310       ARG  South America  Argentina  2020-01-01          NaN        NaN
# 14311       ARG  South America  Argentina  2020-01-02          NaN        NaN
# 14312       ARG  South America  Argentina  2020-01-03          NaN        NaN
# 14313       ARG  South America  Argentina  2020-01-04          NaN        NaN
# 14314       ARG  South America  Argentina  2020-01-05          NaN        0.0
# ...         ...            ...        ...         ...          ...        ...
# 281084      PER  South America       Peru  2024-05-08    4524748.0        0.0
# 281085      PER  South America       Peru  2024-05-09    4524748.0        0.0
# 281086      PER  South America       Peru  2024-05-10    4524748.0        0.0
# 281087      PER  South America       Peru  2024-05-11    4524748.0        0.0
# 281088      PER  South America       Peru  2024-05-12    4524748.0        0.0
#
# ...

# %%
pd.set_option('display.max_rows',10)
paises_andinos = paises_andinos[['location','date','new_cases_smoothed']]
paises_andinos
# Out:
#          location        date  new_cases_smoothed
# 14310   Argentina  2020-01-01                 NaN
# 14311   Argentina  2020-01-02                 NaN
# 14312   Argentina  2020-01-03                 NaN
# 14313   Argentina  2020-01-04                 NaN
# 14314   Argentina  2020-01-05                 NaN
# ...           ...         ...                 ...
# 281084       Peru  2024-05-08                 0.0
# 281085       Peru  2024-05-09                 0.0
# 281086       Peru  2024-05-10                 0.0
# 281087       Peru  2024-05-11                 0.0
# 281088       Peru  2024-05-12                 0.0
#
# [6364 rows x 3 columns]

# %%
# Eliminar filas con valores NaN en la columna 'new_cases_smoothed'
paises_andinos = paises_andinos.dropna(subset=['new_cases_smoothed'])
paises_andinos
# Out:
#          location        date  new_cases_smoothed
# 14319   Argentina  2020-01-10                 0.0
# 14320   Argentina  2020-01-11                 0.0
# 14321   Argentina  2020-01-12                 0.0
# 14322   Argentina  2020-01-13                 0.0
# 14323   Argentina  2020-01-14                 0.0
# ...           ...         ...                 ...
# 281084       Peru  2024-05-08                 0.0
# 281085       Peru  2024-05-09                 0.0
# 281086       Peru  2024-05-10                 0.0
# 281087       Peru  2024-05-11                 0.0
# 281088       Peru  2024-05-12                 0.0
#
# [6340 rows x 3 columns]

# %%
# Calcular el total de nuevos casos suavizados para cada país
total_por_pais = paises_andinos.groupby('location')['new_cases_smoothed'].sum()
pd.set_option('display.float_format',lambda x: '%.0f' % x)
# Mostrar el resultado
print(total_por_pais)
# Out:
# location
# Argentina   10131825
# Bolivia      1212131
# Chile        5400017
# Peru         4524748
# Name: new_cases_smoothed, dtype: float64
