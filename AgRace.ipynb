# %% [markdown]
# <a href="https://colab.research.google.com/github/JnLuck/BigData/blob/main/AgRace.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Instalar la librería 'bar-chart-race'
# !pip install bar-chart-race
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 kB 1.2 MB/s eta 0:00:00
# ...

# %%
# Importar pandas
import pandas as pd

# %%
# Leer el archivo CSV
datos = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vQ8PYMyIMAehxVldmwpdA_UefszoyWPqMQiqavhUAEqFG23TPIzXl_2Cuh8mI6r33NGYcNsvZ-9BZJl/pub?gid=1988003933&single=true&output=csv",index_col="MESES",)

# %%
# Listar datos
datos
# Out:
#          MEXICO   PERU
# MESES
# 2020-01  326.22  271.1
# 2020-02  307.52  259.2
# 2020-03  347.10  183.5
# 2020-04  203.23   72.4
# 2020-05  251.40   99.2
# 2020-06  327.39  226.1
# 2020-07  367.00  194.1
# 2020-08  389.93  227.1
# 2020-09  288.61  250.8
# 2020-10  309.21  249.6
# 2020-11  325.36  253.6
# 2020-12  366.17  274.2
# 2021-01  330.00  238.9
# 2021-02  344.26  253.7
# 2021-03  363.43  252.9
# 2021-04  358.91  243.2
# 2021-05  355.44  264.4
# 2021-06  364.17  267.1
# 2021-07  364.30  277.5
# 2021-08  342.27  287.5
# 2021-09  358.45  261.1
# 2021-10  322.52  253.9
# 2021-11  331.05  255.9
# 2021-12  341.16  277.9
# 2022-01  347.20  241.1
# 2022-02  348.01  229.5
# 2022-03  353.72  230.6
# 2022-04  351.75  234.5
# 2022-05  355.13  239.4
# 2022-06  368.95  243.8
# 2022-07  348.01  237.0
# 2022-08  355.58  258.8
# 2022-09  348.98  241.4
# 2022-10  341.95  250.6
# 2022-11  334.33  230.8
# 2022-12  329.25  261.9

# %%
# Importar la librería 'bar_chart_race' y asignarle el alias 'bcarrera'
import bar_chart_race as bcarrera

# %%
# Crear un gráfico de barras animado utilizando el DataFrame 'datos'
bcarrera.bar_chart_race(df=datos,filename="ag.mp4")
# Out:
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
