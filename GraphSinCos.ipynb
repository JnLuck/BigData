# %% [markdown]
# <a href="https://colab.research.google.com/github/JnLuck/BigData/blob/main/GraphSinCos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importar matplotlib para graficar y numpy
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # **Gráfico Seno y Coseno (Lineas)**

# %%
# Generar valores para el eje x de -10 a 10 con paso de 0.25
x = np.arange(20, 50, 0.1)

# Calcular los valores de seno y coseno correspondientes a cada valor de x
y1 = np.sin(x)
y2 = np.cos(x)

# Crear una figura de tamaño 10x6 pulgadas para el gráfico
plt.figure(figsize=(10, 6))

# Graficar la función seno como puntos azules ('b') con etiqueta 'Seno'
plt.plot(x, y1, color='b', label='Seno')

# Graficar la función coseno como puntos rojos ('r') con etiqueta 'Coseno'
plt.plot(x, y2, color='r', label='Coseno')

# Etiquetar el eje x como 'x'
plt.xlabel('x')

# Etiquetar el eje y como 'y'
plt.ylabel('y')

# Establecer el título del gráfico como 'Funciones Seno y Coseno'
plt.title('Gráfico de las Funciones Seno y Coseno')

# Mostrar la leyenda del gráfico
plt.legend()

# Establecer los límites del eje y de -2 a 2
plt.ylim(-2, 2)

# Mostrar una cuadrícula en el gráfico
plt.grid(True)

# Mostrar el gráfico en pantalla
plt.show()

# %% [markdown]
# # **Gráfico Seno y Coseno (Puntos)**

# %%
# Generar valores para el eje x de -10 a 10 con paso de 0.25
x = np.arange(-10, 10, 0.25)

# Calcular los valores de seno y coseno correspondientes a cada valor de x
y1 = np.sin(x)
y2 = np.cos(x)

# Crear una figura de tamaño 10x6 pulgadas para el gráfico
plt.figure(figsize=(10, 6))

# Graficar la función seno como puntos azules ('b') con etiqueta 'Seno'
plt.scatter(x, y1, color='b', label='Seno')

# Graficar la función coseno como puntos rojos ('r') con etiqueta 'Coseno'
plt.scatter(x, y2, color='r', label='Coseno')

# Etiquetar el eje x como 'x'
plt.xlabel('x')

# Etiquetar el eje y como 'y'
plt.ylabel('y')

# Establecer el título del gráfico como 'Funciones Seno y Coseno'
plt.title('Funciones Seno y Coseno')

# Mostrar la leyenda del gráfico
plt.legend()

# Establecer los límites del eje y de -2 a 2
plt.ylim(-2, 2)

# Mostrar una cuadrícula en el gráfico
plt.grid(True)

# Mostrar el gráfico en pantalla
plt.show()

# %% [markdown]
# # **Gráficos: Seno, Coseno, Tangente y Cuadrática**

# %%
# Generar valores para el eje x de -10 a 10 con paso de 0.25
x = np.arange(-10, 10, 0.25)

# Calcular los valores de las funciones
y_seno = np.sin(x)
y_coseno = np.cos(x)
y_tangente = np.tan(x)
y_cuadratica = x**2

# Configurar el gráfico con un solo plano cartesiano
plt.figure(figsize=(12, 8))

# Graficar el seno
plt.subplot(2, 2, 1)
plt.plot(x, y_seno, label='Seno', color='b')
plt.legend()
plt.grid(True)
plt.title('Seno')

# Graficar el coseno
plt.subplot(2, 2, 2)
plt.plot(x, y_coseno, label='Coseno', color='r')
plt.legend()
plt.grid(True)
plt.title('Coseno')

# Graficar la tangente
plt.subplot(2, 2, 3)
plt.plot(x, y_tangente, label='Tangente', color='g')
plt.legend()
plt.grid(True)
plt.title('Tangente')

# Graficar la función cuadrática
plt.subplot(2, 2, 4)
plt.plot(x, y_cuadratica, label='Cuadrática', color='purple')
plt.legend()
plt.grid(True)
plt.title('Cuadrática')

# Ajustar espacio entre subgráficos
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # **Gráficos: Seno, Coseno, Tangente, Cuadrática, Linea1 y Linea2**

# %%
# Generar valores para el eje x de -10 a 10 con paso de 0.25
x = np.arange(-10, 10, 0.25)

# Calcular los valores de las funciones
y_seno = np.sin(x)
y_coseno = np.cos(x)
y_tangente = np.tan(x)
y_cuadratica = x**2

# Configurar el gráfico con un solo plano cartesiano
plt.figure(figsize=(12, 8))

# Graficar el seno
plt.subplot(3, 2, 1)
plt.plot(x, y_seno, label='Seno', color='b')
plt.legend()
plt.grid(True)
plt.title('Seno')

# Graficar el coseno
plt.subplot(3, 2, 2)
plt.plot(x, y_coseno, label='Coseno', color='r')
plt.legend()
plt.grid(True)
plt.title('Coseno')

# Graficar la tangente
plt.subplot(3, 2, 3)
plt.plot(x, y_tangente, label='Tangente', color='g')
plt.legend()
plt.grid(True)
plt.title('Tangente')

# Graficar la función cuadrática
plt.subplot(3, 2, 4)
plt.plot(x, y_cuadratica, label='Cuadrática', color='purple')
plt.legend()
plt.grid(True)
plt.title('Cuadrática')

# Graficar la primera recta en el quinto subgráfico
plt.subplot(3, 2, 5)
plt.plot(x, 2*x + 1, label='y = 2x + 1', color='pink')
plt.legend()
plt.grid(True)
plt.title('Recta 1')

# Graficar la segunda recta en el sexto subgráfico
plt.subplot(3, 2, 6)
plt.plot(x, -3*x + 5, label='y = -3x + 5', color='c')
plt.legend()
plt.grid(True)
plt.title('Recta 2')

# Ajustar espacio entre subgráficos
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # **Gráficos: Seno, Coseno, Tangente y Cuadrática (Fila)**

# %%
# Generar valores para el eje x de -10 a 10 con paso de 0.25
x = np.arange(-10, 10, 0.25)

# Calcular los valores de las funciones
y_seno = np.sin(x)
y_coseno = np.cos(x)
y_tangente = np.tan(x)
y_cuadratica = x**2

# Configurar el gráfico con un solo plano cartesiano
plt.figure(figsize=(12, 8))

# Graficar el seno
plt.subplot(2, 1, 1)
plt.plot(x, y_seno, label='Seno', color='b')
plt.legend()
plt.grid(True)
plt.title('Seno')

# Graficar el coseno
plt.subplot(2, 2, 2)
plt.plot(x, y_coseno, label='Coseno', color='r')
plt.legend()
plt.grid(True)
plt.title('Coseno')

# Graficar la tangente
plt.subplot(2, 2, 3)
plt.plot(x, y_tangente, label='Tangente', color='g')
plt.legend()
plt.grid(True)
plt.title('Tangente')

# Graficar la función cuadrática
plt.subplot(2, 2, 4)
plt.plot(x, y_cuadratica, label='Cuadrática', color='purple')
plt.legend()
plt.grid(True)
plt.title('Cuadrática')

# Ajustar espacio entre subgráficos
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # **Gráficos: Seno, Coseno, Tangente y Cuadrática (Columna)**

# %%
# Generar valores para el eje x de -10 a 10 con paso de 0.25
x = np.arange(-10, 10, 0.25)

# Calcular los valores de las funciones
y_seno = np.sin(x)
y_coseno = np.cos(x)
y_tangente = np.tan(x)
y_cuadratica = x**2

# Configurar el gráfico con un solo plano cartesiano
plt.figure(figsize=(12, 8))

# Graficar el seno
plt.subplot(4, 1, 1)
plt.plot(x, y_seno, label='Seno', color='b')
plt.legend()
plt.grid(True)
plt.title('Seno')

# Graficar el coseno
plt.subplot(4, 1, 2)
plt.plot(x, y_coseno, label='Coseno', color='r')
plt.legend()
plt.grid(True)
plt.title('Coseno')

# Graficar la tangente
plt.subplot(4, 1, 3)
plt.plot(x, y_tangente, label='Tangente', color='g')
plt.legend()
plt.grid(True)
plt.title('Tangente')

# Graficar la función cuadrática
plt.subplot(4, 1, 4)
plt.plot(x, y_cuadratica, label='Cuadrática', color='purple')
plt.legend()
plt.grid(True)
plt.title('Cuadrática')

# Ajustar espacio entre subgráficos
plt.tight_layout()

# Mostrar el gráfico
plt.show()
